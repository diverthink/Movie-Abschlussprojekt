# %%
import visualisation_data_cleaning
import pandas as pd

data_new = visualisation_data_cleaning.visual_data()
# Out:
# Lese Datei: c:\Users\diver\Desktop\GitHub\Repositories\Movie-Abschlussprojekt\Data\1960\merged_movies_data_1960.csv
# Lese Datei: c:\Users\diver\Desktop\GitHub\Repositories\Movie-Abschlussprojekt\Data\1961\merged_movies_data_1961.csv
# Lese Datei: c:\Users\diver\Desktop\GitHub\Repositories\Movie-Abschlussprojekt\Data\1962\merged_movies_data_1962.csv
# Lese Datei: c:\Users\diver\Desktop\GitHub\Repositories\Movie-Abschlussprojekt\Data\1963\merged_movies_data_1963.csv
# Lese Datei: c:\Users\diver\Desktop\GitHub\Repositories\Movie-Abschlussprojekt\Data\1964\merged_movies_data_1964.csv
# Lese Datei: c:\Users\diver\Desktop\GitHub\Repositories\Movie-Abschlussprojekt\Data\1965\merged_movies_data_1965.csv
# Lese Datei: c:\Users\diver\Desktop\GitHub\Repositories\Movie-Abschlussprojekt\Data\1966\merged_movies_data_1966.csv
# Lese Datei: c:\Users\diver\Desktop\GitHub\Repositories\Movie-Abschlussprojekt\Data\1967\merged_movies_data_1967.csv
# ...

# %%
data_new.head(5)
# Out:
#                    Title                                         Movie Link  \
# 0  Swiss Family Robinson  https://www.imdb.com/title/tt0054357/?ref_=sr_t_1
# 1                 Psycho  https://www.imdb.com/title/tt0054215/?ref_=sr_t_2
# 2          The Apartment  https://www.imdb.com/title/tt0053604/?ref_=sr_t_3
# 3              Spartacus  https://www.imdb.com/title/tt0054331/?ref_=sr_t_4
# 4             Breathless  https://www.imdb.com/title/tt0053472/?ref_=sr_t_5
#
#    Year  Duration  Rating     Votes  \
# 0  1960       126     7.1   19000.0
# 1  1960       109     8.5  745000.0
# 2  1960       125     8.3  206000.0
# 3  1960       197     7.9  147000.0
# 4  1960        90     7.7   90000.0
#
#                                          Description      Budget  \
# 0  A Swiss family must survive being shipwrecked ...   5000000.0
# 1  A secretary on the run for embezzlement takes ...    806947.0
# 2  A Manhattan insurance clerk tries to rise in h...   3000000.0
# ...

# %% [markdown]
# old columns: 'Title', 'Movie Link', 'Year', 'Duration', 'Rating', 'Votes',
#        'Description', 'budget', 'grossWorldWide', 'gross_US_Canada',
#        'opening_weekend_Gross', 'directors', 'writers', 'stars',
#        'countries_origin', 'filming_locations', 'production_companies',
#        'Languages', 'wins', 'nominations', 'oscars', 'release_date', 'id',
#        'MPA_category', 'inflation_gross_opening', 'budget_inflation',
#        'has_oscars', 'decade', 'main_genres'
#
# new columns: 'Title', 'Movie Link', 'Year', 'Duration', 'Rating', 'Votes',
#        'Description', 'Budget', 'World Wide Gross', 'North America Gross', 'Opening Weekend Gross', 'Directors',
#        'Writers', 'Stars', 'Origin Countries', 'Filming Locations', 'Production Companies', 'Languages', 'Award Wins', 'Award Nominations',
#        'Oscar Nominations', 'release_date', 'id', 'MPA', 'Inflation Adjusted Opening Gross', 'Inflation Adjusted Budget', 'Nominated for Oscar',
#        'Decade', 'Genres'
